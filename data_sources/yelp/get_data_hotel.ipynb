# %% [markdown]
# # Yelp Hotels

# %% [markdown]
# **[Work in progress]**
#
# This notebook creates a .csv file with yelp information for ingestion into the Knowledge Graph.

# %%
import os
import json
import pandas as pd

from pathlib import Path
from yelpapi import YelpAPI
from pprint import pprint

# %%
# read yelp api key
with open('key.data', 'r') as key:
    api_key = key.read()

yelp_api = YelpAPI(api_key)

# %%
def float_range(start, stop, step):
    while round(start, 6) < stop:
        yield float(round(start, 6))
        start += step

# %%
term = 'hotel'

# 1 degree: approximately 111 km
# using step size of 0.009 degree
start_latitude = 32.550 # 32.670 # 32.710
stop_latitude = 33.100 # 32.770 # 32.750
step_latitude = 0.090

# 1 degree: approximaely 93 km
# using step size of 0.010 degree
start_longitude = -117.260 # -117.260 # -117.175
stop_longitude = -116.900 # -117.100 # -117.140
step_longitude = 0.100

# radius of search 500m
radius = 5000

# yelp api offset and limit
offset = 0
limit = 50

# %%
zone = list()
for lat in float_range(start_latitude, stop_latitude, step_latitude * 1.3):
    for long in float_range(start_longitude, stop_longitude, step_longitude):
        zone.append((lat, long))
        
for lat in float_range(start_latitude + step_latitude/1.45, stop_latitude, step_latitude * 1.3):
    for long in float_range(start_longitude + step_longitude/2, stop_longitude, step_longitude):
        zone.append((lat, long))
        
print('Number of coordinates: {}'.format(len(zone)))
# Out:
# Number of coordinates: 40

# %%
import folium
import random as rnd

zone_center = [
    round((start_latitude + stop_latitude - step_latitude) / 2, 3), 
    round((start_longitude + stop_longitude - step_longitude) / 2, 3)
]
print(zone_center)

# Build map 
map_zone = folium.Map(location=zone_center, zoom_start=10, tiles='cartodbpositron', width=800, height=600)

# folium.CircleMarker(zone_center, radius=1, color='#00FF00', fill_color='#0080bb').add_to(map_zone)
folium.Rectangle(zone, color='#0080bb', fill_color='#0080bb').add_to(map_zone)

for i in range(len(zone)):
    folium.CircleMarker(zone[i], radius=1, color='#FF0000', fill_color='#0080bb').add_to(map_zone)
    folium.Circle(zone[i], radius=radius, color='#FF0000', fill_color='#0080bb').add_to(map_zone)

map_zone
# Out:
# [32.78, -117.13]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def scrap_yelp(df_combined, latitude, longitude, radius):
    # Maximum 1000 businesses can be pulled
    scrapped = 0
    for i in range(20):
        print('\tScrapping offset: {}'.format(50 * i))
        response = yelp_api.search_query(term=term, latitude=latitude, longitude=longitude, 
                                         limit=limit, radius=radius, offset=scrapped)
        scrapped += len(response['businesses'])
        df = pd.json_normalize(response['businesses'])    

        if df_combined is not None:
            df_combined = pd.concat([df_combined, df], sort=False, ignore_index=True)
        else:       
            df_combined = df.copy()

        # More to scrapped from this location
        if response['total'] <= scrapped:
            print('Completed scrapping. Total: {}'.format(response['total']))
            break
    return df_combined.copy()

# %%
df_business = None 
for latitude, longitude in zone:
    print('Scrapping coordinate: ({}, {}). Radius: {}'.format(latitude, longitude, radius))
    df_business = scrap_yelp(df_business, latitude, longitude, radius)
# Out:
# Scrapping coordinate: (32.55, -117.26). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 0
# Scrapping coordinate: (32.55, -117.16). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 10
# Scrapping coordinate: (32.55, -117.06). Radius: 5000
# 	Scrapping offset: 0
# 	Scrapping offset: 50
# Completed scrapping. Total: 68
# Scrapping coordinate: (32.55, -116.96). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 29
# Scrapping coordinate: (32.667, -117.26). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 2
# Scrapping coordinate: (32.667, -117.16). Radius: 5000
# 	Scrapping offset: 0
# 	Scrapping offset: 50
# Completed scrapping. Total: 73
# Scrapping coordinate: (32.667, -117.06). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 38
# Scrapping coordinate: (32.667, -116.96). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 3
# Scrapping coordinate: (32.784, -117.26). Radius: 5000
# 	Scrapping offset: 0
# 	Scrapping offset: 50
# Completed scrapping. Total: 78
# Scrapping coordinate: (32.784, -117.16). Radius: 5000
# 	Scrapping offset: 0
# 	Scrapping offset: 50
# Completed scrapping. Total: 93
# Scrapping coordinate: (32.784, -117.06). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 28
# Scrapping coordinate: (32.784, -116.96). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 23
# Scrapping coordinate: (32.901, -117.26). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 19
# Scrapping coordinate: (32.901, -117.16). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 22
# Scrapping coordinate: (32.901, -117.06). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 3
# Scrapping coordinate: (32.901, -116.96). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 2
# Scrapping coordinate: (33.018, -117.26). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 22
# Scrapping coordinate: (33.018, -117.16). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 7
# Scrapping coordinate: (33.018, -117.06). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 9
# Scrapping coordinate: (33.018, -116.96). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 0
# Scrapping coordinate: (32.612069, -117.21). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 0
# Scrapping coordinate: (32.612069, -117.11). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 43
# Scrapping coordinate: (32.612069, -117.01). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 8
# Scrapping coordinate: (32.612069, -116.91). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 2
# Scrapping coordinate: (32.729069, -117.21). Radius: 5000
# 	Scrapping offset: 0
# 	Scrapping offset: 50
# 	Scrapping offset: 100
# 	Scrapping offset: 150
# 	Scrapping offset: 200
# Completed scrapping. Total: 228
# Scrapping coordinate: (32.729069, -117.11). Radius: 5000
# 	Scrapping offset: 0
# 	Scrapping offset: 50
# 	Scrapping offset: 100
# Completed scrapping. Total: 125
# Scrapping coordinate: (32.729069, -117.01). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 16
# Scrapping coordinate: (32.729069, -116.91). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 1
# Scrapping coordinate: (32.846069, -117.21). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 33
# Scrapping coordinate: (32.846069, -117.11). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 13
# Scrapping coordinate: (32.846069, -117.01). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 8
# Scrapping coordinate: (32.846069, -116.91). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 13
# Scrapping coordinate: (32.963069, -117.21). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 16
# Scrapping coordinate: (32.963069, -117.11). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 8
# Scrapping coordinate: (32.963069, -117.01). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 4
# Scrapping coordinate: (32.963069, -116.91). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 3
# Scrapping coordinate: (33.080069, -117.21). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 4
# Scrapping coordinate: (33.080069, -117.11). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 8
# Scrapping coordinate: (33.080069, -117.01). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 1
# Scrapping coordinate: (33.080069, -116.91). Radius: 5000
# 	Scrapping offset: 0
# Completed scrapping. Total: 2

# %%
len(df_business)
# Out:
# 1065

# %%
df_business = df_business.drop_duplicates(subset=['id'])

# %%
len(df_business)
# Out:
# 641

# %%
columns={
    'coordinates.latitude':'coordinates_latitude',
    'coordinates.longitude':'coordinates_longitude',    
    'location.address1':'location_address1',
    'location.address2':'location_address2',
    'location.address3':'location_address3',
    'location.city':'location_city',
    'location.zip_code':'location_zip_code',
    'location.country':'location_country',
    'location.state':'location_state',
    'location.display_address':'location_display_address',
}
df_business_final = df_business.rename(columns=columns)

# %%
df_business_final.head()
# Out:
#                        id                                              alias  \
# 0  QDL0yIR_Bo3q4gAEklGwqw   pier-south-resort-autograph-collection-san-diego
# 1  CKwcE4SjL8AiCyPGSHz6jg  hampton-inn-and-suites-imperial-beach-san-dieg...
# 2  ZgwVcuvUSh-BXpQeNFU0wg        sand-castle-inn-and-suites-imperial-beach-2
# 3  wn_SsQj1PTMEipeRuPkhCA                                hotel-jatay-tijuana
# 4  bkp166SyrH5PgGvxmHctkQ                               hotel-martín-tijuana
#
#                                             name  \
# 0        Pier South Resort, Autograph Collection
# 1  Hampton Inn & Suites Imperial Beach San Diego
# 2                       Sand Castle Inn & Suites
# 3                                    Hotel Jatay
# 4                                   Hotel Martín
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/1qvrGs...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/p_Hgf1...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/mFpNf6...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/2KeYBK...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/WQOLi8...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/pier-south-resort-aut...           207
# 1  https://www.yelp.com/biz/hampton-inn-and-suite...             6
# 2  https://www.yelp.com/biz/sand-castle-inn-and-s...             9
# 3  https://www.yelp.com/biz/hotel-jatay-tijuana?a...             7
# 4  https://www.yelp.com/biz/hotel-mart%C3%ADn-tij...             1
#
#                                           categories  rating transactions  \
# 0  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     3.5           []
# 1           [{'alias': 'hotels', 'title': 'Hotels'}]     4.5           []
# 2           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 3           [{'alias': 'hotels', 'title': 'Hotels'}]     2.5           []
# 4           [{'alias': 'hotels', 'title': 'Hotels'}]     5.0           []
#
#    ... coordinates_latitude coordinates_longitude  \
# 0  ...            32.581374           -117.132280
# 1  ...            32.583865           -117.116161
# 2  ...            32.581920           -117.131460
# 3  ...            32.531237           -117.122986
# 4  ...            32.533617           -117.123087
#
#                                    location_address1  location_address2  \
# 0                                 800 Seacoast Drive
# 1                                       771 Palm Ave               None
# 2                                    785 Seacoast Dr               None
# 3                                Av Del Pacifico 570
# 4  Av. Del Pacífico 4, Sección Monumental, Playas...
#
#    location_address3   location_city location_zip_code location_country  \
# 0                          San Diego             91932               US
# 1               None  Imperial Beach             91932               US
# 2                     Imperial Beach             91932               US
# 3               None         Tijuana             22504               MX
# 4                            Tijuana             22504               MX
#
#   location_state                           location_display_address
# 0             CA          [800 Seacoast Drive, San Diego, CA 91932]
# 1             CA           [771 Palm Ave, Imperial Beach, CA 91932]
# 2             CA        [785 Seacoast Dr, Imperial Beach, CA 91932]
# 3            BCN  [Av Del Pacifico 570, 22504 Tijuana, Baja Cali...
# 4            BCN  [Av. Del Pacífico 4, Sección Monumental, Playa...
#
# [5 rows x 24 columns]

# %%
with open('./../../data/yelp_hotel.csv', 'w') as f:
    df_business_final.to_csv(f, index=False)

# %%
df_csv = pd.read_csv('./../../data/yelp_hotel.csv')

# %%
df_coordinates = df_csv[['coordinates_latitude', 'coordinates_longitude']].dropna()

# %%
# Build map 
map_zone = folium.Map(location=zone_center, zoom_start=10, tiles='cartodbpositron', width=800, height=600)
for i in range(len(df_coordinates)):
    folium.CircleMarker((df_coordinates.iloc[i][0], df_coordinates.iloc[i][1]), 
                        radius=1, color='#FF0000', fill_color='#0080bb').add_to(map_zone)
map_zone
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
len(df_csv)
# Out:
# 641

# %%
# df_review = None
start_again = False
for i, business_id in enumerate(df_csv['id']):
    if not start_again:
        if business_id == 'BVtSyHjWuk3tYCy986wl1g':
            start_again = True
    else:
        response = yelp_api.reviews_query(id=business_id)
        df = pd.json_normalize(response['reviews'])
        df.insert(0, 'business_id', business_id) 

        if df_review is not None:
            df_review = pd.concat([df_review, df], sort=False, ignore_index=True)
        else:       
            df_review = df.copy()
    
    if i % 100 == 0:
        print('Processing business #{}'.format(i + 1))
# Out:
# Processing business #1
# Processing business #101
# Processing business #201
# Processing business #301
# Processing business #401
# Processing business #501
# Processing business #601

# %%
len(df_review)
# Out:
# 1763

# %%
df_review.tail(5)
# Out:
#                  business_id                      id  \
# 1758  2LsSOLbxHNgCnwbffv_LGQ  98oF1FUbtgbMPuNNjhvXmw
# 1759  bUk83zR-0jTXfGVtSfjVMw  4VM2Zhw_8bXxQp3pFgF9nQ
# 1760  bUk83zR-0jTXfGVtSfjVMw  0VirC5TGJ_zd0JZy53MwUw
# 1761  bUk83zR-0jTXfGVtSfjVMw  p5aXqmWDQyxplv3nlQuYWw
# 1762  okcun7M5291OfhEl8Y9_PQ  jM2EzALwawhjgpaiftCMnw
#
#                                                     url  \
# 1758  https://www.yelp.com/biz/the-ranch-at-bandy-ca...
# 1759  https://www.yelp.com/biz/ramona-valley-inn-ram...
# 1760  https://www.yelp.com/biz/ramona-valley-inn-ram...
# 1761  https://www.yelp.com/biz/ramona-valley-inn-ram...
# 1762  https://www.yelp.com/biz/old-ramona-hotel-gall...
#
#                                                    text  rating  \
# 1758  I found the only perfect place to go during Co...     5.0
# 1759  This is your basic sleep over room environment...     3.0
# 1760  I discussed each issue with the hotel. Parking...     2.0
# 1761  If I was able to give "zero stars" I would.  W...     1.0
# 1762  First off, this place is the best kept secret ...     5.0
#
#              time_created                 user.id  \
# 1758  2020-09-13 07:29:20  ulQXGLfDXNuqd0yMavQ-Aw
# 1759  2019-02-13 18:58:11  KgvIuqrFDOUgJqQxI9wDuQ
# 1760  2020-09-23 15:13:10  9XCGBvNM-RuvqPV6Yf34cA
# 1761  2020-10-24 11:31:46  Lstey-hLLBRpgqqnHOq2Xw
# 1762  2019-08-29 14:20:19  ZuQQUZuqO9xrhMDOMKxsgw
#
#                                        user.profile_url  \
# 1758  https://www.yelp.com/user_details?userid=ulQXG...
# 1759  https://www.yelp.com/user_details?userid=KgvIu...
# 1760  https://www.yelp.com/user_details?userid=9XCGB...
# 1761  https://www.yelp.com/user_details?userid=Lstey...
# 1762  https://www.yelp.com/user_details?userid=ZuQQU...
#
#                                          user.image_url user.name
# 1758                                               None  Elyse M.
# 1759  https://s3-media1.fl.yelpcdn.com/photo/nM6B_tK...  Steve H.
# 1760  https://s3-media2.fl.yelpcdn.com/photo/c7lzFMM...   Mark H.
# 1761                                               None   Eric S.
# 1762  https://s3-media4.fl.yelpcdn.com/photo/k_Vt7Jj...   Need T.

# %%
df_review = df_review.drop_duplicates(subset=['id'])

# %%
columns={
    'user.id':'user_id',
    'user.profile_url':'user_profile_url',    
    'user.image_url':'user_image_url',
    'user.name':'user_name',
}
df_review_final = df_review.rename(columns=columns)

# %%
with open('./../../data/yelp_hotel_review.csv', 'w') as f:
    df_review_final.to_csv(f, index=False)
