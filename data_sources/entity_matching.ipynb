# %% [markdown]
# # Imports and functions

# %%
import pandas as pd
import py_entitymatching as em
import py_stringmatching as sm

from math import radians, sin, cos, asin, sqrt

# %% [markdown]
# # Read CSV Files

# %%
# Other terms: restaurant, attraction, hotel
term = 'restaurant'

# %%
A = em.read_csv_metadata('./../data/yelp_{}.csv'.format(term), key='id', low_memory=False)
B = em.read_csv_metadata('./../data/google_{}.csv'.format(term), key='place_id', low_memory=False)
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
print('Number of tuples in A: {}'.format(len(A)))
print('Number of tuples in B: {}'.format(len(B)))
print('Number of tuples in A X B (i.e the cartesian product): {}'.format(len(A) * len(B)))
# Out:
# Number of tuples in A: 6064
# Number of tuples in B: 6130
# Number of tuples in A X B (i.e the cartesian product): 37172320

# %%
# Display the keys of the input tables
em.get_key(A), em.get_key(B)
# Out:
# ('id', 'place_id')

# %%
A1 = A[['id', 'name', 'location_display_address', 'phone', 
        'coordinates_latitude', 'coordinates_longitude']].copy()
B1 = B[['place_id', 'name', 'formatted_address', 'formatted_phone_number', 
        'geometry_location_lat', 'geometry_location_lng']].copy()

# %% [markdown]
# # Down Sampling

# %%
# Down sampling the datasets to 1000 for development purposes
# Comment out for actual data
A1, B1 = em.down_sample(A[['id', 'name', 'location_display_address', 'phone', 
                           'coordinates_latitude', 'coordinates_longitude']], 
                        B[['place_id', 'name', 'formatted_address', 'formatted_phone_number', 
                           'geometry_location_lat', 'geometry_location_lng']], 
                        size=500, y_param=1, show_progress=True)

# %%
print('Number of tuples in A1: {}'.format(len(A1)))
print('Number of tuples in B1: {}'.format(len(B1)))
print('Number of tuples in A1 X B1 (i.e the cartesian product): {}'.format(len(A1) * len(B1)))
# Out:
# Number of tuples in A1: 6064
# Number of tuples in B1: 6130
# Number of tuples in A1 X B1 (i.e the cartesian product): 37172320

# %% [markdown]
# # Preprocess

# %%
def phone_string_process(x):
    try:
        return str(int(x)).lstrip('1')
    except ValueError:
        return x

# %%
A1['name'] = A1['name'].str.lower()
A1['name'] = A1['name'].str.replace('restaurant', '')

A1['location_display_address'] = A1['location_display_address'].str.lower()
A1['location_display_address'] = A1['location_display_address'].str.strip('[]')
A1['location_display_address'] = A1['location_display_address'].str.replace('\'', '')
A1['location_display_address'] = A1['location_display_address'].str.replace('#', '')
A1['location_display_address'] = A1['location_display_address'].str.replace(',', '')

A1['phone'] = A1['phone'].apply(phone_string_process)
                                                                            
A1 = A1.rename(columns={
    'location_display_address': 'address',
    'phone': 'phone', 
    'coordinates_latitude': 'lat',
    'coordinates_longitude': 'long', 
})

B1['name'] = B1['name'].str.lower()
B1['name'] = B1['name'].str.replace('restaurant', '')

B1['formatted_address'] = B1['formatted_address'].str.lower()
B1['formatted_address'] = B1['formatted_address'].str.replace('\'', '')
B1['formatted_address'] = B1['formatted_address'].str.replace('#', '')
B1['formatted_address'] = B1['formatted_address'].str.replace(',', '')

B1['formatted_phone_number'] = B1['formatted_phone_number'].str.replace('(', '')
B1['formatted_phone_number'] = B1['formatted_phone_number'].str.replace(')', '')
B1['formatted_phone_number'] = B1['formatted_phone_number'].str.replace('-', '')
B1['formatted_phone_number'] = B1['formatted_phone_number'].str.replace(' ', '')

B1 = B1.rename(columns={
    'formatted_address': 'address', 
    'formatted_phone_number': 'phone', 
    'geometry_location_lat': 'lat',
    'geometry_location_lng': 'long', 
})

# %%
yelp_sample = './../data/yelp_{}_sample.csv'.format(term)
google_sample = './../data/google_{}_sample.csv'.format(term)

# %%
# Saving the down sampled data for reuse.
em.to_csv_metadata(A1, yelp_sample)
em.to_csv_metadata(B1, google_sample)
# Out:
# File already exists at ./../data/yelp_restaurant_sample.csv; Overwriting it
# File already exists at ./../data/google_restaurant_sample.csv; Overwriting it
# True

# %%
# Data profiling and exploration
A1 = em.read_csv_metadata(yelp_sample, key='id', low_memory=False)
B1 = em.read_csv_metadata(google_sample, key='place_id', low_memory=False)
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.

# %% [markdown]
# # Block tables

# %%
A1['phone'] = A1['phone'].astype(str).str.replace('\.0', '')
B1['phone'] = B1['phone'].astype(str).str.replace('\.0', '')

# %%
def haversine(lon1, lat1, lon2, lat2, unit='km'):
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    if unit == 'km':
        return 2 * 6371 * asin(sqrt(a))
    elif unit == 'mile':
        return (2 * 6371 * asin(sqrt(a))) / 1.609344

# %%
jac = sm.Jaccard()
qg3_tok = sm.QgramTokenizer(qval=3)
def name_address_function(x, y):
    x_name = x['name']
    x_address = x['address']
    x_phone = x['phone']
    x_lat = x['lat']
    x_long = x['long']
    
    y_name = y['name']
    y_address = y['address']
    y_phone = y['phone']
    y_lat = y['lat']
    y_long = y['long']

    # Name must be available
    if type(x_name) != str or type(y_name) != str:
        return True
    
    distance = haversine(x_long, x_lat, y_long, y_lat)
    if distance > 5:
        return True
    else:
        if x_phone != 'nan' and y_phone != 'nan':
            if x_phone == y_phone:
                return False        
        
        t1 = qg3_tok.tokenize(x_name)
        t2 = qg3_tok.tokenize(y_name)
        name = bool(jac.get_raw_score(t1, t2) < 0.15)
        
        if distance > 1:
            if type(x_address) != str or type(y_address) != str:
                return True 
            else:
                t1 = qg3_tok.tokenize(x_address)
                t2 = qg3_tok.tokenize(y_address)
                address = bool(jac.get_raw_score(t1, t2) < 0.7)
                return address or name
        else:
            return name

# %%
# Instantiate blackbox blocker
bb = em.BlackBoxBlocker()

# Set the black box function
bb.set_black_box_function(name_address_function)

C = bb.block_tables(A1, B1, 
                    l_output_attrs=['name', 'address', 'phone', 'lat', 'long'],
                    r_output_attrs=['name', 'address', 'phone', 'lat', 'long'], 
                    show_progress=True)

print('Pairs found: {}'.format(len(C)))
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:25:18
# Pairs found: 11641

# %%
C.head(3)
# Out:
#    _id               ltable_id              rtable_place_id  \
# 0    0  AJ1SJkAVv1H6lA4pDnZ0dQ  ChIJvekefj5J2YAR57-HHVQJ3aI
# 1    1  uGt9jvS6tcPpYhJa1kDl1w  ChIJGVvXXaxJ2YARa8nlE2r3oU0
# 2    2  9BeEPZ4p0iEHYyKLYBLRBw  ChIJy6XT-j5J2YAR4kxAymYsYgM
#
#              ltable_name                             ltable_address  \
# 0               ying li   342 w san ysidro blvd san ysidro ca 92173
# 1  la cachonda cenaduria   347 w san ysidro blvd san diego ca 92173
# 2            zappy pizza   416 w san ysidro blvd san diego ca 92173
#
#   ltable_phone  ltable_lat  ltable_long  rtable_name  \
# 0   6194282288   32.554284  -117.050823     ying li
# 1          nan   32.555684  -117.051453  la cachonda
# 2   6196909232   32.554764  -117.052038  zappy pizza
#
#                                    rtable_address rtable_phone  rtable_lat  \
# 0  342 w san ysidro blvd n san diego ca 92173 usa   6194282288   32.554340
# 1    347 w san ysidro blvd san diego ca 92173 usa   6192269077   32.555638
# 2   416 w san ysidro blvd san ysidro ca 92173 usa   6196909232   32.554762
#
#    rtable_long
# 0  -117.050951
# 1  -117.051133
# 2  -117.052111

# %% [markdown]
# # Debug blocker output

# %%
# Display first few tuple pairs from the debug_blocker's output
# to make sure tuples are not blocking incorrectly
dbg = em.debug_blocker(C, A1, B1, output_size=50)
dbg
# Out:
#     _id               ltable_id              rtable_place_id  \
# 0     0  JyU1gtpMwTwvtPKXHe9_vg  ChIJl2fxNz4H3IARWidudy2KvW4
# 1     1  pmVf8dKK4ACHG4ogRalVAw  ChIJnY_6HeNR2YARN5aVz2wjFsY
# 2     2  _7RajSyuMNOliMHF_YsN4w  ChIJv0giDDFV2YARkfyYqpGntP8
# 3     3  LLT2FUyNMaxaKtzq8UdQvw  ChIJl2fxNz4H3IARWidudy2KvW4
# 4     4  VPyFEPULX3G9hLlQM5lRVg  ChIJj90A8fNV2YARWFIcQUhNzQQ
# 5     5  9CWFWngCc5-TFguk0a39Bg  ChIJKa3A8pr_24ARA8KqYL-7fqM
# 6     6  LZoTHYCaqSfrdnrPJLKGmw  ChIJickSuW1F2YARscGvqpTYzYk
# 7     7  TgqlE7Y_OZY3OHq9FL-e2Q  ChIJl7qt8xUH3IARpIXzVKKrI5I
# 8     8  dR0ZnLpRlnIIswZyGP-8Lg  ChIJ2xvq4w6q3oARsArmidIU0tc
# 9     9  bMQsXDRNSgukAiWBphJDMA  ChIJPcE9Tnf524ARMVP_yXJzdrU
# 10   10  0JVOztoUbjCmz-Ej97ycaQ  ChIJl2fxNz4H3IARWidudy2KvW4
# 11   11  6sqCRUQld4i8CV6MNmm4wQ  ChIJNSRmzcEH3IARK0303829FDA
# 12   12  BjzrBlgGi80rtUes-KN_Sg  ChIJNz11lI5T2YARSvlVaETsLsA
# 13   13  BjzrBlgGi80rtUes-KN_Sg  ChIJIWxn8ddT2YARxVZ4kUYmsyI
# 14   14  9CWFWngCc5-TFguk0a39Bg  ChIJMRlm95n_24ARMBjwDFEOAVw
# 42   42  JQi0VbqAxZ2h_-Im69iiag  ChIJ5T7VjsZV2YARXgjoRsBbTrI
# 43   43  HuY5ggMRrg1sKtTnz-a-Lw  ChIJIWxn8ddT2YARxVZ4kUYmsyI
# 44   44  MgPL7zbSebBUYS-gpeSDzA  ChIJk0bgOBGr3oARo1WA0YOXd1Y
# 45   45  pmVf8dKK4ACHG4ogRalVAw  ChIJI8drkA9R2YARl6hcHwqNCpw
# 46   46  MgPL7zbSebBUYS-gpeSDzA  ChIJO2q1FRar3oARBBCEsYD5heM
# 47   47  pmVf8dKK4ACHG4ogRalVAw  ChIJwyt_HeNR2YARBYZ1JLLcUe4
# 48   48  kab2juI_zc2aJ55jtpyzuA  ChIJNSRmzcEH3IARXSQ0XbJYBgc
# 49   49  HTQzAy0wlKz4CdYSD64N4Q  ChIJdUZGmhar3oARG62fPLyQaTA
#
#               ltable_name  \
# 0                  dr j's
# 1                sharky's
# 2            cafe terrace
# 3         fricken burgers
# 4             chick-fil-a
# 5             korean food
# 6                 wendy's
# 7          sorrento court
# 8                   draft
# 9                    ihop
# 10              all spice
# 11                addison
# 12             pizza port
# 13             pizza port
# 14            korean food
# 15        jack in the box
# 16        jack in the box
# 17              beaudevin
# 18        emerald express
# 19      tamales el mexico
# 20            korean food
# 21               covewood
# 22        jack in the box
# 23        explorer's cafe
# 24        emerald express
# 25           price center
# 26               sharky's
# 27          lucky seafood
# 28          panda express
# 29               wurstnox
# 30              beaudevin
# 31               stir fry
# 32          panda express
# 33        jack in the box
# 34           artisan cafe
# 35         a.r. valentien
# 36        jack in the box
# 37        jack in the box
# 38        jack in the box
# 39  liberty public market
# 40     cecilia's taqueria
# 41             west winds
# 42        jack in the box
# 43             west winds
# 44              beaudevin
# 45               sharky's
# 46              beaudevin
# 47               sharky's
# 48                  amaya
# 49        jack in the box
#
#                                                          ltable_address  \
# 0                                   9645 scranton rd san diego ca 92121
# 1                           3030 plaza bonita rd national city ca 91950
# 2                                     7007 friars rd san diego ca 92108
# 3                                   9645 scranton rd san diego ca 92121
# 4                             5323 mission center rd san diego ca 92108
# 5                          7655 clairemont mesa blvd san diego ca 92111
# 6                               2260 otay lakes rd chula vista ca 91915
# 7                                   9450 scranton rd san diego ca 92121
# 8                              3105 ocean front walk san diego ca 92109
# 9                                8440 mira mesa blvd san diego ca 92126
# 10                                  9645 scranton rd san diego ca 92121
# 11          the grand del mar 5200 grand del mar way san diego ca 92130
# 12                          100 park blvd petco park san diego ca 92101
# 13                          100 park blvd petco park san diego ca 92101
# 14                         7655 clairemont mesa blvd san diego ca 92111
# 15                                   7015 broadway lemon grove ca 91945
# 16                                       4011 bonita rd bonita ca 91902
# 17                                  3225 n harbor dr san diego ca 92101
# 18                                  3225 n harbor dr san diego ca 92101
# 19                               3842 university ave san diego ca 92105
# 20                         7655 clairemont mesa blvd san diego ca 92111
# 21                             1775 e mission bay dr san diego ca 92109
# 48   8583142727                   hotel fairmont grand del mar
# 49   6192970095                                jack in the box
#
#                                                                              rtable_address  \
# 0                                                   9645 scranton rd san diego ca 92121 usa
# 1                                           3030 plaza bonita rd national city ca 91950 usa
# 2                                                 7007 friars rd 356 san diego ca 92108 usa
# 3                                                   9645 scranton rd san diego ca 92121 usa
# 4                                             5323 mission center rd san diego ca 92108 usa
# 5                                               clairemont mesa blvd san diego ca 92111 usa
# 6                                               2260 otay lakes rd chula vista ca 91915 usa
# 7                                             9450 scranton rd  114a san diego ca 92121 usa
# 8                                              3105 ocean front walk san diego ca 92109 usa
# 9                                                8440 mira mesa blvd san diego ca 92126 usa
# 10                                                  9645 scranton rd san diego ca 92121 usa
# 11                                            5200 grand del mar way san diego ca 92130 usa
# 12                                                     100 park blvd san diego ca 92101 usa
# 13                                                     100 park blvd san diego ca 92101 usa
# 14                                         7655 clairemont mesa blvd san diego ca 92111 usa
# 15                                                   7979 broadway lemon grove ca 91945 usa
# 16                                                      plaza bonita rd bonita ca 91902 usa
# 17                                                  3225 n harbor dr san diego ca 92101 usa
# 18                                                  3225 n harbor dr san diego ca 92101 usa
# 19                                               3850 university ave san diego ca 92105 usa
# 20                                         7655 clairemont mesa blvd san diego ca 92111 usa
# 21                                             1775 e mission bay dr san diego ca 92109 usa
# 22                                                   7015 broadway lemon grove ca 91945 usa
# 23                                                  500 sea world dr san diego ca 92109 usa
# 24                                                  3225 n harbor dr san diego ca 92101 usa
# 25                                   price center 9500 gilman dr 1327 la jolla ca 92093 usa
# 26                                          3030 plaza bonita rd national city ca 91950 usa
# 27                                               9326 mira mesa blvd san diego ca 92126 usa
# 28                                                  3225 n harbor dr san diego ca 92101 usa
# 29                                          4545 la jolla village dr san diego ca 92122 usa
# 30                                                  3225 n harbor dr san diego ca 92101 usa
# 31                                                  500 sea world dr san diego ca 92109 usa
# 32                                                  3225 n harbor dr san diego ca 92101 usa
# 33                                        terminal 1 west space 1024 san diego ca 92101 usa
# 34  san diego international airport terminal 2 east 3225 n harbor dr san diego ca 92101 usa
# 35                                            11480 n torrey pines rd la jolla ca 92037 usa
# 36                                                     802 3rd ave chula vista ca 91911 usa
# 37                                                    1408 3rd ave chula vista ca 91911 usa
# 38                                             7425 mission gorge rd san diego ca 92120 usa
# 39                    liberty public market 2820 historic decatur rd san diego ca 92106 usa
# 40                                          2820 historic decatur rd san diego ca 92106 usa
# 41                                                     100 park blvd san diego ca 92101 usa
# 42                                             6080 mission gorge rd san diego ca 92120 usa
# 43                                                     100 park blvd san diego ca 92101 usa
# 44                                                  3225 n harbor dr san diego ca 92101 usa
# 45                                          3030 plaza bonita rd national city ca 91950 usa
# 46                                                  3225 n harbor dr san diego ca 92101 usa
# 47                                          3030 plaza bonita rd national city ca 91950 usa
# 48                                             5300 grand del mar ct san diego ca 92130 usa
# 49                                             terminal 2 space 2035 san diego ca 92101 usa
#
#    rtable_phone
# 0           nan
# 1    6194752175
# 2           nan
# 3           nan
# 4           nan
# 5           nan
# 6    6196518691
# 7           nan
# 8    8582289304
# 9           nan
# 10          nan
# 11   8583142700
# 12          nan
# 13          nan
# 14          nan
# 15   6194634800
# 16          nan
# 17          nan
# 18          nan
# 19          nan
# 20          nan
# 21   0915008943
# 22   6194602529
# 23          nan
# 24          nan
# 25   8586388212
# 26          nan
# 27   8585783606
# 28          nan
# 29   8584571044
# 30          nan
# 31          nan
# 32          nan
# 33   6192970095
# 34          nan
# 35   8587776641
# 36   6194251791
# 37   6194203902
# 38   6192652188
# 39   6192090140
# 40   6194879346
# 41          nan
# 42   6193251799
# 43          nan
# 44          nan
# 45          nan
# 46          nan
# 47          nan
# 48   8583142000
# 49   6192970095

# %% [markdown]
# # Label the candidate set

# %%
# Sample candidate set
S = em.sample_table(C, 200)

# %%
# Label candidate S
G = em.label_table(S, 'label')
# Out:
# Column name (label) is not present in dataframe

# %%
sample_table_labeled = './../data/sample_block_labeled.csv'

# %%
# Saving the labeled data for future reuse
G.to_csv(sample_table_labeled, index=False)

# %%
# Load the labeled data
G = em.read_csv_metadata(sample_table_labeled, 
                         key='_id',
                         ltable=A1, rtable=B1, 
                         fk_ltable='ltable_id', fk_rtable='rtable_place_id')
print('Total labeled pairs: {}'.format(len(G)))
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Total labeled pairs: 200

# %%
G['ltable_phone'] = G['ltable_phone'].astype(str).str.replace('\.0', '')
G['rtable_phone'] = G['rtable_phone'].astype(str).str.replace('\.0', '')

# %%
G.head(3)
# Out:
#    _id               ltable_id              rtable_place_id  \
# 0   13  a6yxQHge4tcaKGV2lt4U3A  ChIJAcUnsB5J2YAROQmXCiUl9SU
# 1   84  VZXziy0PZlxWtq7czOXyIw  ChIJC2KlzwBH2YARwrf5itjOiCA
# 2  150  mBU-fwzP8-E_h58PheAuRA  ChIJ6RPgoAlH2YAR69Mu53CASyc
#
#                  ltable_name  \
# 0           tuetano taqueria
# 1  don lucio's mexican grill
# 2           mariscos chuky's
#
#                                                           ltable_address  \
# 0                               143 w san ysidro blvd san diego ca 92173
# 1                  2360 paseo de las americas ste 105 san diego ca 92154
# 2  av. jose lopez portillo pte. s/n 22436 tijuana baja california mexico
#
#   ltable_phone  ltable_lat  ltable_long            rtable_name  \
# 0   6198567013   32.553240  -117.045900    taqueria revolución
# 1   6196611577   32.555074  -116.936443  don lucio's taco shop
# 2          nan   32.538170  -116.930360      mariscos altamura
#
#                                                                                         rtable_address  \
# 0                                                         362 e san ysidro blvd san diego ca 92173 usa
# 1                                                                  2498 roll dr san diego ca 92154 usa
# 2  blvd. de las bellas artes lbnueva tijuana22435 tijuana b.c. blvd. de las bellas artes lb nueva t...
#
#   rtable_phone  rtable_lat  rtable_long  label
# 0   6196903187   32.550714  -117.038357      0
# 1   6196611577   32.555085  -116.936428      1
# 2          nan   32.543547  -116.935393      0

# %% [markdown]
# # Split the labeled data

# %%
# Split S into development set (I) and evaluation set (J)
IJ = em.split_train_test(G, train_proportion=0.8, random_state=1)
I = IJ['train']
J = IJ['test']

# %%
# Create a set of ML-matchers
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')
nb = em.NBMatcher(name='NaiveBayes')

# %%
match_c = em.get_attr_corres(A1, B1)

# %%
match_tok = em.get_tokenizers_for_matching()
match_sim = em.get_sim_funs_for_matching()

atypes1 = em.get_attr_types(A1)
atypes2 = em.get_attr_types(B1)

feature_table = em.get_features(A1, B1, atypes1, atypes2, match_c, match_tok, match_sim)

# %%
feature_table = feature_table[(feature_table.left_attribute == 'name') | 
                              (feature_table.left_attribute == 'address') |
                              (feature_table.left_attribute == 'phone')]

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=feature_table, 
                            attrs_after='label',
                            show_progress=True)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00

# %%
# Evaluate ML matcher using CV=4
result = em.select_matcher([dt, rf, svm, ln, lg, nb], table=H,
                           exclude_attrs=['_id', 'ltable_id', 'rtable_place_id', 'label'],
                           k=4,
                           target_attr='label', metric_to_select_matcher='f1', 
                           random_state=0)

result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.887363        0.874812    0.875082
# 1            RF           0.936688        0.910652    0.922408
# 2           SVM           0.968750        0.735464    0.835033
# 3        LinReg           0.907452        0.943985    0.921572
# 4        LogReg           0.958333        0.909461    0.932346
# 5    NaiveBayes           0.959375        0.926128    0.940948

# %% [markdown]
# #  Predict on test data

# %%
# Convert J into a set of feature vectors using feature table
L = em.extract_feature_vecs(J, 
                            feature_table=feature_table,
                            attrs_after='label', 
                            show_progress=True)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00

# %%
# Train using feature vectors from I 
lg.fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_place_id', 'label'], 
       target_attr='label')

# %%
# Predict on L 
predictions = lg.predict(table=L, 
                         exclude_attrs=['_id', 'ltable_id', 'rtable_place_id', 'label'], 
                         append=True, 
                         target_attr='predicted', 
                         inplace=False)

# %%
# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'label', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 78.57% (11/14)
# Recall : 91.67% (11/12)
# F1 : 84.62%
# False positives : 3 (out of 14 positive predictions)
# False negatives : 1 (out of 26 negative predictions)

# %%
# Print the out to check the false positive/negative cases if any
final = J.copy() 
final['predicted'] = predictions['predicted']
final.head()
# Out:
#        _id               ltable_id              rtable_place_id  \
# 58    3810  qj3g9Wtn8rGChIRG5kcTKQ  ChIJQSo5cbpU2YARFW66pe7BXao
# 40    2292  8PwGhzqDu_nvD7SNkU2jvw  ChIJOfZ1-QdT2YARkZS-h2MLGGY
# 34    1874  5n-7uAIGTWSVo5ZpYQWdWw  ChIJG_Rs7q5U2YARRdmnSHcpVEQ
# 102   6772  dTK7MogmexEKaruicqSR4A  ChIJFz9l4AZY2YAR0YIosBlmiqc
# 184  10959  teew2mRsrEirerG4VKNmVg  ChIJk9OXZz4H3IARGa8RC-3Oeb4
#
#                   ltable_name  \
# 58   bankers hill bar & grill
# 40        hodads - petco park
# 34                    the owl
# 102   hilberto's mexican food
# 184             sher e punjab
#
#                                                    ltable_address  \
# 58   3225 n harbor dr terminal 1 e fl 2 gate 7 san diego ca 92101
# 40                               100 park blvd san diego ca 92101
# 34                                602 broadway san diego ca 92101
# 102                             9805 prospect ave santee ca 92071
# 184                   9254 scranton rd ste 102 san diego ca 92121
#
#     ltable_phone  ltable_lat  ltable_long                     rtable_name  \
# 58    6192310222   32.732550  -117.196260             bankers hill bar +
# 40           nan   32.706269  -117.156465  randy jones grill - petco park
# 34    6195010123   32.715950  -117.158950                  the kebab shop
# 102   6192588313   32.831040  -116.983310          santana's mexican food
# 184   8584582858   32.890894  -117.201661  sher-e-punjab -sorrento valley
#
#                                   rtable_address rtable_phone  rtable_lat  \
# 58        2202 fourth ave san diego ca 92101 usa   6192310222   32.728410
# 40          100 park blvd san diego ca 92101 usa          nan   32.706373
# 34         303 w beech st san diego ca 92101 usa   6195505481   32.720721
# 102   10050 mission gorge rd santee ca 92071 usa   6196317680   32.838151
# 184  9254 scranton rd 102 san diego ca 92121 usa   8584582858   32.891127
#
#      rtable_long  label  predicted
# 58   -117.161357      0          0
# 40   -117.157145      0          0
# 34   -117.165780      0          0
# 102  -116.977874      0          0
# 184  -117.201719      1          0

# %% [markdown]
# #  Predict on full blocking data

# %%
# Convert C into a set of feature vectors using feature table
L = em.extract_feature_vecs(C, 
                            feature_table=feature_table, 
                            show_progress=True)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:17

# %%
# Predict on L
predictions = lg.predict(table=L, 
                         exclude_attrs=['_id', 'ltable_id', 'rtable_place_id'], 
                         append=True, 
                         target_attr='predicted', 
                         inplace=False)

# %%
# Print the out to check the false positive/negative cases if any
data_all = C.copy() 
data_all['predicted'] = predictions['predicted']

# %%
data_positive = data_all[data_all['predicted'] == 1]

# %%
print('Total unique left table: {}'.format(data_positive['ltable_id'].nunique()))
print('Total unique right table: {}'.format(data_positive['rtable_place_id'].nunique()))
print('Total match: {}'.format(len(data_positive)))
# Out:
# Total unique left table: 4401
# Total unique right table: 4430
# Total match: 4501

# %%
# Unique value
unique_positive = data_positive.drop_duplicates(subset=['ltable_id'])
unique_positive = unique_positive.drop_duplicates(subset=['rtable_place_id'])

print('Total unique left table: {}'.format(unique_positive['ltable_id'].nunique()))
print('Total unique right table: {}'.format(unique_positive['rtable_place_id'].nunique()))
print('Total match: {}'.format(len(unique_positive)))
# Out:
# Total unique left table: 4349
# Total unique right table: 4349
# Total match: 4349

# %%
unique_positive.to_csv('./../data/{}_match.csv'.format(term), index=False)
