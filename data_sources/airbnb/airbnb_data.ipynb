# %%
import json
import os
import pandas as pd

from airbnb_api import Airbnb

# %% [markdown]
# # Data

# %%
# location of saved data
data_path = '../../data'

# %%
# load neighborhoods identified in Airbnb data
with open(os.path.join(data_path, 'SDneighborhoods.txt'), 'r') as f:
    neighborhoods = f.read().splitlines()

# %%
# load listings
listings_file = os.path.join(data_path, 'airbnb-listings-full.json')

if os.path.exists(listings_file):
    listings = pd.read_json(listings_file)
    listings = listings.drop_duplicates(subset='id')
else:
    listings = pd.DataFrame()

num_listings = len(listings)
num_listings
# Out:
# 7320

# %%
listings.head()
# Out:
#   badges  bathroom_label  bathrooms bed_label bedroom_label  bedrooms  beds  \
# 0     []   1 shared bath        1.0     1 bed     1 bedroom       1.0   1.0
# 1  [NEW]  1 private bath        1.0     1 bed     1 bedroom       1.0   1.0
# 2     []          1 bath        1.0     1 bed        Studio       0.0   1.0
# 3     []          1 bath        1.0     1 bed     1 bedroom       1.0   1.0
# 4     []          1 bath        1.0     1 bed        Studio       0.0   1.0
#
#           city guest_label host_languages  ... price_string  \
# 0  Chula Vista    5 guests             []  ...          $35
# 1    San Diego    2 guests             []  ...          $30
# 2    San Diego    2 guests             []  ...          $77
# 3    San Diego     1 guest       [en, es]  ...          $25
# 4    San Diego    2 guests       [en, es]  ...          $67
#
#                                                 rate  rate_type  \
# 0  {'amount': 35.0, 'amount_formatted': '$35', 'c...    nightly
# 1  {'amount': 30.0, 'amount_formatted': '$30', 'c...    nightly
# 2  {'amount': 77.0, 'amount_formatted': '$77', 'c...    nightly
# 3  {'amount': 25.0, 'amount_formatted': '$25', 'c...    nightly
# 4  {'amount': 67.0, 'amount_formatted': '$67', 'c...    nightly
#
#                                rate_with_service_fee  weekly_price_factor  \
# 0  {'amount': 35.0, 'amount_formatted': '$35', 'c...                 0.93
# 1  {'amount': 30.0, 'amount_formatted': '$30', 'c...                 0.95
# 2  {'amount': 77.0, 'amount_formatted': '$77', 'c...                 1.00
# 3  {'amount': 25.0, 'amount_formatted': '$25', 'c...                 1.00
# 4  {'amount': 67.0, 'amount_formatted': '$67', 'c...                 0.95
#
#    should_show_from_label china_promotion_display_types  license  \
# 0                   False                            []     None
# 1                   False                            []     None
# 2                   False                            []     None
# 3                   False                            []     None
# 4                   False                            []     None
#
#    trust_signals summary
# 0           None    None
# 1           None    None
# 2           None    None
# 3           None    None
# 4           None    None
#
# [5 rows x 78 columns]

# %%
# load reviews
reviews_file = os.path.join(data_path, 'airbnb-reviews-full.json')

if os.path.exists(reviews_file):
    reviews = pd.read_json(reviews_file)
    reviews = reviews.drop_duplicates(subset='id')
else:
    reviews = pd.DataFrame()

num_reviews = len(reviews)
num_reviews
# Out:
# 426207

# %%
reviews.head()
# Out:
#                                               author  author_id  \
# 0  {'first_name': 'Reginald', 'has_profile_pic': ...  328321073
# 1  {'first_name': 'Reginald', 'has_profile_pic': ...  328321073
# 2  {'first_name': 'John', 'has_profile_pic': True...   31735215
# 3  {'first_name': 'Lawang', 'has_profile_pic': Tr...  212339508
# 4  {'first_name': 'Brittany', 'has_profile_pic': ...  124868001
#
#    can_be_edited                                           comments  \
# 0          False                                        magnificent
# 1          False  I have been Garry's guest for the last 6 month...
# 2          False  Gary is a wonderful host.\nHe is very nice and...
# 3          False  Recommended to all for a cozy place with great...
# 4          False  Gary was very friendly and welcoming! And the ...
#
#                  created_at         id     id_str  listing_id  recipient_id  \
# 0 2020-08-20 22:48:25+00:00  653954608  653954608    13301630      40442827
# 1 2020-06-15 23:46:10+00:00  629997649  629997649    13301630      40442827
# 2 2019-12-29 00:59:02+00:00  583538843  583538843    13301630      40442827
# 3 2018-09-03 22:56:57+00:00  318521505  318521505    13301630      40442827
# 4 2018-07-22 23:49:03+00:00  295091676  295091676    13301630      40442827
#
#    collection_tag                                            listing  rating  \
# 0             NaN  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 1             NaN  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 2             NaN  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 3             NaN  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 4             NaN  {'id': 13301630, 'listing_id_str': '13301630',...       5
#
#                                            recipient response   role language  \
# 0  {'first_name': 'Gary', 'has_profile_pic': True...           guest       en
# 1  {'first_name': 'Gary', 'has_profile_pic': True...           guest       en
# 2  {'first_name': 'Gary', 'has_profile_pic': True...           guest       en
# 3  {'first_name': 'Gary', 'has_profile_pic': True...           guest       en
# 4  {'first_name': 'Gary', 'has_profile_pic': True...           guest       en
#
#    user_flag
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# # API

# %%
# instantiate Airbnb API wrapper
airbnb = Airbnb()

# %%
# get listings (306 appears to be the maximum for a single query)
new_listings = airbnb.get_listings('San Diego, CA')
# Out:
# No results for San Diego, CA on page 1

# %%
new_listings

# %%
def save_data(df, filename):
    """
    Save DataFrame as JSON in nicer format than pandas.DataFrame.to_json
    
    Parameters:
        listings (pandas.DataFrame): DataFrame of listings
        filename (str): Name of file
    """

    with open(filename, 'w') as f:
        df_dict = df.to_dict(orient='records')
        print(json.dumps(df_dict, indent=4), file=f)

# %%
listings = listings.append(new_listings).drop_duplicates(subset='id')

if len(listings) > num_listings:
    print('Found new listings!')
    save_data(listings, listings_file)
    num_listings = len(listings)

# %%
# get listings for a couple neighborhoods
new_listings = airbnb.get_neighborhood_listings(['North Park', 'South Park'], 'San Diego, CA')
# Out:
# No results for North Park, San Diego, CA on page 1
# No results for South Park, San Diego, CA on page 1

# %%
new_listings

# %%
listings = listings.append(new_listings).drop_duplicates(subset='id')

if len(listings) > num_listings:
    print('Found new listings!')
    save_data(listings, listings_file)

# %%
# get reviews for a couple listings
new_reviews = airbnb.get_all_reviews(listings.id.values[:2])
new_reviews
# Out:
#                                                author  author_id  \
# 0   {'first_name': 'Reginald', 'has_profile_pic': ...  328321073
# 1   {'first_name': 'Reginald', 'has_profile_pic': ...  328321073
# 2   {'first_name': 'John', 'has_profile_pic': True...   31735215
# 3   {'first_name': 'Lawang', 'has_profile_pic': Tr...  212339508
# 4   {'first_name': 'Brittany', 'has_profile_pic': ...  124868001
# 5   {'first_name': 'Dylan', 'has_profile_pic': Tru...  105593023
# 6   {'first_name': 'Iris', 'has_profile_pic': True...   85397302
# 7   {'first_name': 'Aliki', 'has_profile_pic': Tru...   90637792
# 8   {'first_name': 'Imane', 'has_profile_pic': Tru...   66956170
# 9   {'first_name': 'Dan', 'has_profile_pic': True,...   47112954
# 10  {'first_name': 'Rachel', 'has_profile_pic': Tr...   45144182
# 11  {'first_name': 'Kalpen', 'has_profile_pic': Tr...   80055426
# 12  {'first_name': 'Tatiana', 'has_profile_pic': T...   75374554
# 13  {'first_name': 'Nicholas', 'has_profile_pic': ...   77169326
# 14  {'first_name': 'Natalie', 'has_profile_pic': T...   63947697
# 15  {'first_name': 'Mirjam', 'has_profile_pic': Tr...  138378813
#
#     can_be_edited                                           comments  \
# 0           False                                        magnificent
# 1           False  I have been Garry's guest for the last 6 month...
# 2           False  Gary is a wonderful host.\nHe is very nice and...
# 3           False  Recommended to all for a cozy place with great...
# 4           False  Gary was very friendly and welcoming! And the ...
# 5           False  Gary is so kind and friendly. He would like to...
# 6           False  Gary was kind. He gave us recommendations on b...
# 7           False  This space is unbelievable, perfect for a fami...
# 8           False  Gary is by far the best Airbnb host I've ever ...
# 9           False  Gary is a great host, with a calm relaxing hom...
# 10          False  Gary was very friendly and welcoming. Everythi...
# 11          False  Everything was as per description. Gary was he...
# 12          False  There were 5 of us staying in Gary's place .St...
# 13          False  Gary is an amazing host! The moment we walked ...
# 14          False  Gary was an amazing host ! He even offered 2 f...
# 15          False  Gary is really kind en helpfull.\nThe big room...
#
#               created_at         id     id_str  listing_id  recipient_id  \
# 0   2020-08-20T22:48:25Z  653954608  653954608    13301630      40442827
# 1   2020-06-15T23:46:10Z  629997649  629997649    13301630      40442827
# 2   2019-12-29T00:59:02Z  583538843  583538843    13301630      40442827
# 3   2018-09-03T22:56:57Z  318521505  318521505    13301630      40442827
# 4   2018-07-22T23:49:03Z  295091676  295091676    13301630      40442827
# 5   2017-08-13T20:05:09Z  181982904  181982904    13301630      40442827
# 6   2017-07-17T23:35:17Z  171519718  171519718    13301630      40442827
# 7   2017-02-15T18:29:40Z  132077682  132077682    13301630      40442827
# 8   2016-11-13T19:58:06Z  113796917  113796917    13301630      40442827
# 9   2016-09-05T16:49:21Z   99693193   99693193    13301630      40442827
# 10  2016-08-07T18:06:16Z   92064701   92064701    13301630      40442827
# 11  2016-07-31T15:54:14Z   90215725   90215725    13301630      40442827
# 12  2016-07-26T02:03:34Z   88859081   88859081    13301630      40442827
# 13  2016-06-27T10:26:39Z   82374931   82374931    13301630      40442827
# 14  2016-06-22T04:26:16Z   81267817   81267817    13301630      40442827
# 15  2017-08-16T21:13:52Z  183246590  183246590    13301630      40442827
#
#    collection_tag                                            listing  rating  \
# 0            None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 1            None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 2            None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 3            None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 4            None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 5            None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 6            None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 7            None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 8            None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 9            None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 10           None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 11           None  {'id': 13301630, 'listing_id_str': '13301630',...       4
# 12           None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 13           None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 14           None  {'id': 13301630, 'listing_id_str': '13301630',...       5
# 15           None  {'id': 13301630, 'listing_id_str': '13301630',...       5
#
#                                             recipient response   role  \
# 0   {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 1   {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 2   {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 3   {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 4   {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 5   {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 6   {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 7   {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 8   {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 9   {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 10  {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 11  {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 12  {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 13  {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 14  {'first_name': 'Gary', 'has_profile_pic': True...           guest
# 15  {'first_name': 'Gary', 'has_profile_pic': True...           guest
#
#    language user_flag
# 0        en      None
# 1        en      None
# 2        en      None
# 3        en      None
# 4        en      None
# 5        en      None
# 6        en      None
# 7        en      None
# 8        en      None
# 9        en      None
# 10       en      None
# 11       en      None
# 12       en      None
# 13       en      None
# 14       en      None
# 15       en      None

# %%
reviews = reviews.append(new_reviews).drop_duplicates(subset='id')

if len(reviews) > num_reviews:
    print('Found new reviews!')
    save_data(reviews, reviews_file)
