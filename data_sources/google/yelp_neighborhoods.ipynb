# %% [markdown]
# # Imports and functions

# %%
import json
import pandas as pd
import googlemaps

# %%
# read google api key
with open('key.data', 'r') as key:
    api_key = key.read()

gmaps = googlemaps.Client(key=api_key)

# %% [markdown]
# # Get neighborhood

# %%
# Other terms: restaurant, attraction, hotel
term = 'restaurant'

# %%
df_csv = pd.read_csv('./../../data/yelp_{}.csv'.format(term))

# %%
print('Total records: {}'.format(len(df_csv)))
# Out:
# Total records: 6064

# %%
df_addresses = None  # comment out to continue from last business id
start_again = True  # Set to False to continue from last business id
for i, row_series in df_csv.iterrows():
    row_id = row_series['id']
    if not start_again:
        if row_id == '3dLJkahF7G_zhgqjGMbDJw':
            start_again = True
    else:
        row_lat = row_series['coordinates_latitude']
        row_long = row_series['coordinates_longitude']
        
        if pd.isnull(row_lat) or pd.isnull(row_long):
            continue
        
        coordinate = {'latitude': row_lat, 'longitude': row_long}
        response = gmaps.reverse_geocode(latlng=coordinate, language='en')

        for r in response:
            df_address = pd.json_normalize(r['address_components'])
            df_address.insert(0, 'id', row_id) 

            if df_addresses is not None:
                df_addresses = pd.concat([df_addresses, df_address], sort=False, ignore_index=True)
            else:
                df_addresses = df_address.copy()
            
    if i % 10 == 0:
        print('Processing business #{}'.format(i + 1))
# Out:
# Processing business #1
# Processing business #11
# Processing business #21
# Processing business #31
# Processing business #41
# Processing business #51
# Processing business #61
# Processing business #71
# Processing business #81
# Processing business #91
# Processing business #101
# Processing business #111
# Processing business #121
# Processing business #131
# Processing business #141
# Processing business #151
# Processing business #161
# Processing business #171
# Processing business #181
# Processing business #191
# Processing business #201
# Processing business #211
# Processing business #221
# Processing business #231
# Processing business #241
# Processing business #251
# Processing business #261
# Processing business #271
# Processing business #281
# Processing business #291
# Processing business #301
# Processing business #311
# Processing business #321
# Processing business #331
# Processing business #341
# Processing business #351
# Processing business #361
# Processing business #371
# Processing business #381
# Processing business #391
# Processing business #401
# Processing business #411
# Processing business #421
# Processing business #431
# Processing business #441
# Processing business #451
# Processing business #461
# Processing business #471
# Processing business #481
# Processing business #491
# Processing business #501
# Processing business #511
# Processing business #521
# Processing business #531
# Processing business #541
# Processing business #551
# Processing business #561
# Processing business #571
# Processing business #581
# Processing business #591
# Processing business #601
# Processing business #611
# Processing business #621
# Processing business #631
# Processing business #641
# Processing business #651
# Processing business #661
# Processing business #671
# Processing business #681
# Processing business #691
# Processing business #701
# Processing business #711
# Processing business #721
# Processing business #731
# Processing business #741
# Processing business #751
# Processing business #761
# Processing business #771
# Processing business #781
# Processing business #791
# Processing business #801
# Processing business #811
# Processing business #821
# Processing business #831
# Processing business #841
# Processing business #851
# Processing business #861
# Processing business #871
# Processing business #881
# Processing business #891
# Processing business #901
# Processing business #911
# Processing business #921
# Processing business #931
# Processing business #941
# Processing business #951
# Processing business #961
# Processing business #971
# Processing business #981
# Processing business #991
# Processing business #1001
# Processing business #1011
# Processing business #1021
# Processing business #1031
# Processing business #1041
# Processing business #1051
# Processing business #1061
# Processing business #1071
# Processing business #1081
# Processing business #1091
# Processing business #1101
# Processing business #1111
# Processing business #1121
# Processing business #1131
# Processing business #1141
# Processing business #1151
# Processing business #1161
# Processing business #1171
# Processing business #1181
# Processing business #1191
# Processing business #1201
# Processing business #1211
# Processing business #1221
# Processing business #1231
# Processing business #1241
# Processing business #1251
# Processing business #1261
# Processing business #1271
# Processing business #1281
# Processing business #1291
# Processing business #1301
# Processing business #1311
# Processing business #1321
# Processing business #1331
# Processing business #1341
# Processing business #1351
# Processing business #1361
# Processing business #1371
# Processing business #1381
# Processing business #1391
# Processing business #1401
# Processing business #1411
# Processing business #1421
# Processing business #1431
# Processing business #1441
# Processing business #1451
# Processing business #1461
# Processing business #1471
# Processing business #1481
# Processing business #1491
# Processing business #1501
# Processing business #1511
# Processing business #1521
# Processing business #1531
# Processing business #1541
# Processing business #1551
# Processing business #1561
# Processing business #1571
# Processing business #1581
# Processing business #1591
# Processing business #1601
# Processing business #1611
# Processing business #1621
# Processing business #1631
# Processing business #1641
# Processing business #1651
# Processing business #1661
# Processing business #1671
# Processing business #1681
# Processing business #1691
# Processing business #1701
# Processing business #1711
# Processing business #1721
# Processing business #1731
# Processing business #1741
# Processing business #1751
# Processing business #1761
# Processing business #1771
# Processing business #1781
# Processing business #1791
# Processing business #1801
# Processing business #1811
# Processing business #1821
# Processing business #1831
# Processing business #1841
# Processing business #1851
# Processing business #1861
# Processing business #1871
# Processing business #1881
# Processing business #1891
# Processing business #1901
# Processing business #1911
# Processing business #1921
# Processing business #1931
# Processing business #1941
# Processing business #1951
# Processing business #1961
# Processing business #1971
# Processing business #1981
# Processing business #1991
# Processing business #2001
# Processing business #2011
# Processing business #2021
# Processing business #2031
# Processing business #2041
# Processing business #2051
# Processing business #2061
# Processing business #2071
# Processing business #2081
# Processing business #2091
# Processing business #2101
# Processing business #2111
# Processing business #2121
# Processing business #2131
# Processing business #2141
# Processing business #2151
# Processing business #2161
# Processing business #2171
# Processing business #2181
# Processing business #2191
# Processing business #2201
# Processing business #2211
# Processing business #2221
# Processing business #2231
# Processing business #2241
# Processing business #2251
# Processing business #2261
# Processing business #2271
# Processing business #2281
# Processing business #2291
# Processing business #2301
# Processing business #2311
# Processing business #2321
# Processing business #2331
# Processing business #2341
# Processing business #2351
# Processing business #2361
# Processing business #2371
# Processing business #2381
# Processing business #2391
# Processing business #2401
# Processing business #2411
# Processing business #2421
# Processing business #2431
# Processing business #2441
# Processing business #2451
# Processing business #2461
# Processing business #2471
# Processing business #2481
# Processing business #2491
# Processing business #2501
# Processing business #2511
# Processing business #2521
# Processing business #2531
# Processing business #2541
# Processing business #2551
# Processing business #2561
# Processing business #2571
# Processing business #2581
# Processing business #2591
# Processing business #2601
# Processing business #2611
# Processing business #2621
# Processing business #2631
# Processing business #2641
# Processing business #2651
# Processing business #2661
# Processing business #2671
# Processing business #2681
# Processing business #2691
# Processing business #2701
# Processing business #2711
# Processing business #2721
# Processing business #2731
# Processing business #2741
# Processing business #2751
# Processing business #2761
# Processing business #2771
# Processing business #2781
# Processing business #2791
# Processing business #2801
# Processing business #2811
# Processing business #2821
# Processing business #2831
# Processing business #2841
# Processing business #2851
# Processing business #2861
# Processing business #2871
# Processing business #2881
# Processing business #2891
# Processing business #2901
# Processing business #2911
# Processing business #2921
# Processing business #2931
# Processing business #2941
# Processing business #2951
# Processing business #2961
# Processing business #2971
# Processing business #2981
# Processing business #2991
# Processing business #3001
# Processing business #3011
# Processing business #3021
# Processing business #3031
# Processing business #3041
# Processing business #3051
# Processing business #3061
# Processing business #3071
# Processing business #3081
# Processing business #3091
# Processing business #3101
# Processing business #3111
# Processing business #3121
# Processing business #3131
# Processing business #3141
# Processing business #3151
# Processing business #3161
# Processing business #3171
# Processing business #3181
# Processing business #3191
# Processing business #3201
# Processing business #3211
# Processing business #3221
# Processing business #3231
# Processing business #5151
# Processing business #5161
# Processing business #5171
# Processing business #5181
# Processing business #5191
# Processing business #5201
# Processing business #5211
# Processing business #5221
# Processing business #5231
# Processing business #5241
# Processing business #5251
# Processing business #5261
# Processing business #5271
# Processing business #5281
# Processing business #5291
# Processing business #5301
# Processing business #5311
# Processing business #5321
# Processing business #5331
# Processing business #5341
# Processing business #5351
# Processing business #5361
# Processing business #5371
# Processing business #5381
# Processing business #5391
# Processing business #5401
# Processing business #5411
# Processing business #5421
# Processing business #5431
# Processing business #5441
# Processing business #5451
# Processing business #5461
# Processing business #5471
# Processing business #5481
# Processing business #5491
# Processing business #5501
# Processing business #5511
# Processing business #5521
# Processing business #5531
# Processing business #5541
# Processing business #5551
# Processing business #5561
# Processing business #5571
# Processing business #5581
# Processing business #5591
# Processing business #5601
# Processing business #5611
# Processing business #5621
# Processing business #5631
# Processing business #5641
# Processing business #5651
# Processing business #5661
# Processing business #5671
# Processing business #5681
# Processing business #5691
# Processing business #5701
# Processing business #5711
# Processing business #5721
# Processing business #5731
# Processing business #5741
# Processing business #5751
# Processing business #5761
# Processing business #5771
# Processing business #5781
# Processing business #5791
# Processing business #5801
# Processing business #5811
# Processing business #5821
# Processing business #5831
# Processing business #5841
# Processing business #5851
# Processing business #5861
# Processing business #5871
# Processing business #5881
# Processing business #5891
# Processing business #5901
# Processing business #5911
# Processing business #5921
# Processing business #5931
# Processing business #5941
# Processing business #5951
# Processing business #5961
# Processing business #5971
# Processing business #5981
# Processing business #5991
# Processing business #6001
# Processing business #6011
# Processing business #6021
# Processing business #6031
# Processing business #6041
# Processing business #6051
# Processing business #6061

# %% [markdown]
# # Attach additional data place

# %%
df_csv['neighborhood'] = np.nan
df_csv['city'] = np.nan
df_csv['county'] = np.nan
df_csv['state'] = np.nan
df_csv['postal_code'] = np.nan
df_csv['country'] = np.nan

# %%
c_neighborhood = 0
c_city = 0
c_county = 0
c_state = 0
c_postal_code = 0
c_country = 0

for index_label, row_series in df_addresses.iterrows():
    row_business_id = row_series['id']
    row_types = row_series['types']
    row_name = row_series['long_name']
    if 'neighborhood' in row_types:
        if pd.isnull(df_csv.loc[(df_csv['id']==row_business_id), 'neighborhood']).any():
            c_neighborhood += 1
            df_csv.loc[(df_csv['id']==row_business_id), 'neighborhood'] = row_name
    elif 'locality' in row_types:
        if pd.isnull(df_csv.loc[(df_csv['id']==row_business_id), 'city']).any():
            c_city += 1
            df_csv.loc[(df_csv['id']==row_business_id), 'city'] = row_name
    elif 'administrative_area_level_2' in row_types:
        if pd.isnull(df_csv.loc[(df_csv['id']==row_business_id), 'county']).any():
            c_county += 1
            df_csv.loc[(df_csv['id']==row_business_id), 'county'] = row_name
    elif 'administrative_area_level_1' in row_types:
        if pd.isnull(df_csv.loc[(df_csv['id']==row_business_id), 'state']).any():
            c_state += 1
            df_csv.loc[(df_csv['id']==row_business_id), 'state'] = row_name
    elif 'postal_code' in row_types:
        if pd.isnull(df_csv.loc[(df_csv['id']==row_business_id), 'postal_code']).any():
            c_postal_code += 1
            df_csv.loc[(df_csv['id']==row_business_id), 'postal_code'] = row_name
    elif 'country' in row_types:
        if pd.isnull(df_csv.loc[(df_csv['id']==row_business_id), 'country']).any():
            c_country += 1
            df_csv.loc[(df_csv['id']==row_business_id), 'country'] = row_name
        
print('neighborhood: {}'.format(c_neighborhood))
print('city: {}'.format(c_city))
print('county: {}'.format(c_county))
print('state: {}'.format(c_state))
print('postal_code: {}'.format(c_postal_code))
print('country: {}'.format(c_country))
print('unique record: {}'.format(df_csv['place_id'].nunique()))
# Out:
# neighborhood: 4290
# city: 6059
# county: 6059
# state: 6059
# postal_code: 6051
# country: 6059

# %%
print('Total records: {}'.format(len(df_csv)))
print('Total adddresses scrapped: {}'.format(len(df_addresses)))
# Out:
# Total records: 6064
# Total adddresses scrapped: 354099

# %%
with open('./../../data/yelp_{}.csv'.format(term), 'w') as f:
    df_csv.to_csv(f, index=False)

# %%
with open('./../../data/yelp_{}_address.csv'.format(term), 'w') as f:
    df_addresses.to_csv(f, index=False)
